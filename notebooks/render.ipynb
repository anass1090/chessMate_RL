# %%
from agents.v12.ppo_agent import PPOAgent
from agents.v12.ppo_opponent import PPOOpponent

# %%
agent = PPOAgent()
opponent = PPOOpponent()

opponent.load("kqk_opponent_v2_stage_2")
agent.load('kqk_ppo_with_opponent_v1_stage_2')
# Out:
# Using device: cuda
# Generating 500 mate-in-1 positions...
# Done.
# Using device: cuda
# Loaded ← models/kqk_opponent_v2_stage_2.pt
# Loaded ← models/kqk_ppo_with_opponent_v1_stage_2.pt

# %%
agent.animate_game(opponent=opponent)

# %%
agent.animate_game(fen='3k4/8/2K5/4Q3/8/8/8/8 w - - 0 1', opponent=opponent)

# %%
agent.animate_game(fen='8/8/8/8/8/1Q1K4/8/4k3 w - - 0 1', opponent=opponent)

# %%
agent.animate_game(fen='8/2Q5/8/2K5/k7/8/8/8 w - - 0 1', opponent=opponent)

# %%
agent.animate_game(fen='8/5Q2/8/5K2/7k/8/8/8 w - - 0 1', opponent=opponent)
