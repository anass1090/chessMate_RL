# %%
from agents.v2.reinforce_agent import ReinforceAgentV2

# %%
agent = ReinforceAgentV2()
agent.train(n_episodes=20_000, gamma=0.99, log_every=2000, n_envs=32, update_freq=512)
# Out:
# Using device: cuda
# Episode 2000/20000
# Episode 4000/20000
# Episode 6000/20000
# Episode 8000/20000
# Episode 10000/20000
# Episode 12000/20000
# Episode 14000/20000
# Episode 16000/20000
# Episode 18000/20000
# Episode 20000/20000

# %%
agent.save("kqk2_reinforce")
# Out:
# Saved → models/kqk2_reinforce.pt

# %%
agent2 = ReinforceAgentV2()
agent2.load("kqk2_reinforce")
agent2.evaluate(n_episodes=10000)
# Out:
# Using device: cuda
# Loaded ← models/kqk2_reinforce.pt
#
# --- Eval (10000 eps) ---
#   checkmate                     : 117
#   fifty_moves                   : 4921
#   insufficient_material         : 4587
#   stalemate                     : 375
#   mean_steps                    : 32.9
#   checkmate_rate                : 1.2%
# {'fifty_moves': 4921,
#  'insufficient_material': 4587,
#  'stalemate': 375,
#  'checkmate': 117,
#  'mean_steps': 32.9113,
#  'checkmate_rate': 0.0117}
