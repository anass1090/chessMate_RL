# %%
from agents.v11.ppo_agent import PPOAgent, generate_eval_set
import utils.board as b

# %%
agent = PPOAgent(
    curriculum_ratio=0.3,
    movement_ratio=0.5
)

agent.mate_pool = b.generate_mate_pool(10_000)

eval_fens = generate_eval_set(n=1000, seed=42)

agent.load("kqk_ppo_v2_stage_3")

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.5
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)

agent.train(
    n_episodes=100_000,
    eval_fens=eval_fens,
    eval_every=10_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.5
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Using device: cuda
# Generating 500 mate-in-1 positions...
# Done.
# Generated eval set (1000 positions) → /home/anass/School/chessMate/agents/v11/eval_set.json
# Loaded ← models/kqk_ppo_v2_stage_3.pt
#
# --- Eval (1000 eps, movement_ratio=0.5) ---
#   checkmate                     : 898
#   missed_mate                   : 11
#   queen_hang                    : 6
#   stalemate                     : 12
#   threefold_repetition          : 73
#   mean_steps                    : 14.2
#   checkmate_rate                : 89.8%
# Mate-in-1 accuracy (greedy): 428/1000 = 42.8%
# Episode 10416/100000  mean_return=7.426
#   [eval] ep=10416  checkmate=92.4%  mean_steps=13.6
# Episode 20336/100000  mean_return=7.457
#   [eval] ep=20336  checkmate=93.4%  mean_steps=13.8
# Episode 30256/100000  mean_return=7.797
#   [eval] ep=30256  checkmate=93.0%  mean_steps=13.5
# Episode 40176/100000  mean_return=7.708
#   [eval] ep=40176  checkmate=94.9%  mean_steps=13.9
# Episode 50096/100000  mean_return=7.635
#   [eval] ep=50096  checkmate=94.0%  mean_steps=14.0
# Episode 60016/100000  mean_return=7.725
#   [eval] ep=60016  checkmate=95.8%  mean_steps=13.6
# Episode 70432/100000  mean_return=7.718
#   [eval] ep=70432  checkmate=95.2%  mean_steps=13.8
# Episode 80352/100000  mean_return=7.734
#   [eval] ep=80352  checkmate=95.6%  mean_steps=13.9
# Episode 90272/100000  mean_return=7.805
#   [eval] ep=90272  checkmate=96.0%  mean_steps=14.1
# Episode 100192/100000  mean_return=7.885
#   [eval] ep=100192  checkmate=95.2%  mean_steps=13.8
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=0.5) ---
#   checkmate                     : 953
#   fifty_moves                   : 1
#   missed_mate                   : 15
#   queen_hang                    : 11
#   stalemate                     : 2
#   threefold_repetition          : 18
#   mean_steps                    : 13.9
#   checkmate_rate                : 95.3%
# Mate-in-1 accuracy (greedy): 493/1000 = 49.3%
# 0.493

# %%
agent.train(
    n_episodes=100_000,
    eval_fens=eval_fens,
    eval_every=10_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.5
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 10416/100000  mean_return=7.747
#   [eval] ep=10416  checkmate=95.5%  mean_steps=13.8
# Episode 20336/100000  mean_return=7.785
#   [eval] ep=20336  checkmate=94.9%  mean_steps=13.6
# Episode 30256/100000  mean_return=7.926
#   [eval] ep=30256  checkmate=96.0%  mean_steps=13.5
# Episode 40176/100000  mean_return=7.837
#   [eval] ep=40176  checkmate=95.4%  mean_steps=13.5
# Episode 50096/100000  mean_return=8.003
#   [eval] ep=50096  checkmate=96.2%  mean_steps=13.7
# Episode 60016/100000  mean_return=7.873
#   [eval] ep=60016  checkmate=95.1%  mean_steps=13.8
# Episode 70432/100000  mean_return=7.885
#   [eval] ep=70432  checkmate=95.7%  mean_steps=13.6
# Episode 80352/100000  mean_return=7.906
#   [eval] ep=80352  checkmate=97.0%  mean_steps=13.6
# Episode 90272/100000  mean_return=7.771
#   [eval] ep=90272  checkmate=96.2%  mean_steps=13.6
# Episode 100192/100000  mean_return=7.751
#   [eval] ep=100192  checkmate=95.6%  mean_steps=13.5
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=0.5) ---
#   checkmate                     : 964
#   missed_mate                   : 20
#   queen_hang                    : 4
#   stalemate                     : 3
#   threefold_repetition          : 9
#   mean_steps                    : 13.5
#   checkmate_rate                : 96.4%
# Mate-in-1 accuracy (greedy): 520/1000 = 52.0%
# 0.52

# %%
agent.train(
    n_episodes=100_000,
    eval_fens=eval_fens,
    eval_every=10_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.5
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 10416/100000  mean_return=8.035
#   [eval] ep=10416  checkmate=96.3%  mean_steps=13.4
# Episode 20336/100000  mean_return=7.989
#   [eval] ep=20336  checkmate=96.9%  mean_steps=13.4
# Episode 30256/100000  mean_return=8.140
#   [eval] ep=30256  checkmate=96.4%  mean_steps=13.4
# Episode 40176/100000  mean_return=7.930
#   [eval] ep=40176  checkmate=95.9%  mean_steps=13.5
# Episode 50096/100000  mean_return=7.850
#   [eval] ep=50096  checkmate=96.6%  mean_steps=13.3
# Episode 60016/100000  mean_return=7.984
#   [eval] ep=60016  checkmate=96.6%  mean_steps=13.2
# Episode 70432/100000  mean_return=7.971
#   [eval] ep=70432  checkmate=96.3%  mean_steps=13.3
# Episode 80352/100000  mean_return=8.077
#   [eval] ep=80352  checkmate=95.6%  mean_steps=13.2
# Episode 90272/100000  mean_return=8.050
#   [eval] ep=90272  checkmate=96.2%  mean_steps=12.9
# Episode 100192/100000  mean_return=8.080
#   [eval] ep=100192  checkmate=94.6%  mean_steps=12.6
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=0.5) ---
#   checkmate                     : 964
#   missed_mate                   : 17
#   queen_hang                    : 7
#   stalemate                     : 1
#   threefold_repetition          : 11
#   mean_steps                    : 12.6
#   checkmate_rate                : 96.4%
# Mate-in-1 accuracy (greedy): 533/1000 = 53.3%
# 0.533

# %%
agent.train(
    n_episodes=100_000,
    eval_fens=eval_fens,
    eval_every=10_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.5
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 10416/100000  mean_return=7.867
#   [eval] ep=10416  checkmate=96.6%  mean_steps=12.8
# Episode 20336/100000  mean_return=8.087
#   [eval] ep=20336  checkmate=96.3%  mean_steps=12.8
# Episode 30256/100000  mean_return=7.984
#   [eval] ep=30256  checkmate=96.6%  mean_steps=12.7
# Episode 40176/100000  mean_return=8.090
#   [eval] ep=40176  checkmate=96.7%  mean_steps=12.7
# Episode 50096/100000  mean_return=8.021
#   [eval] ep=50096  checkmate=96.5%  mean_steps=12.8
# Episode 60016/100000  mean_return=8.034
#   [eval] ep=60016  checkmate=96.6%  mean_steps=12.8
# Episode 70432/100000  mean_return=7.910
#   [eval] ep=70432  checkmate=96.1%  mean_steps=12.8
# Episode 80352/100000  mean_return=8.246
#   [eval] ep=80352  checkmate=96.9%  mean_steps=12.5
# Episode 90272/100000  mean_return=7.836
#   [eval] ep=90272  checkmate=96.2%  mean_steps=12.7
# Episode 100192/100000  mean_return=7.897
#   [eval] ep=100192  checkmate=96.3%  mean_steps=12.6
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=0.5) ---
#   checkmate                     : 962
#   missed_mate                   : 20
#   queen_hang                    : 6
#   threefold_repetition          : 12
#   mean_steps                    : 12.9
#   checkmate_rate                : 96.2%
# Mate-in-1 accuracy (greedy): 534/1000 = 53.4%
# 0.534

# %%
agent.movement_ratio = 0.5

agent.train(
    n_episodes=100_000,
    eval_fens=eval_fens,
    eval_every=10_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.8
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.5
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 10416/100000  mean_return=8.028
#   [eval] ep=10416  checkmate=97.9%  mean_steps=12.4
# Episode 20336/100000  mean_return=8.140
#   [eval] ep=20336  checkmate=97.2%  mean_steps=12.3
# Episode 30256/100000  mean_return=8.038
#   [eval] ep=30256  checkmate=97.8%  mean_steps=12.6
# Episode 40176/100000  mean_return=8.136
#   [eval] ep=40176  checkmate=97.7%  mean_steps=12.5
# Episode 50096/100000  mean_return=7.993
#   [eval] ep=50096  checkmate=97.5%  mean_steps=12.3
# Episode 60016/100000  mean_return=8.145
#   [eval] ep=60016  checkmate=98.0%  mean_steps=12.5
# Episode 70432/100000  mean_return=8.145
#   [eval] ep=70432  checkmate=98.1%  mean_steps=12.4
# Episode 80352/100000  mean_return=8.230
#   [eval] ep=80352  checkmate=97.8%  mean_steps=12.4
# Episode 90272/100000  mean_return=8.223
#   [eval] ep=90272  checkmate=98.0%  mean_steps=12.4
# Episode 100192/100000  mean_return=8.114
#   [eval] ep=100192  checkmate=97.8%  mean_steps=12.3
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=0.8) ---
#   checkmate                     : 975
#   missed_mate                   : 9
#   queen_hang                    : 3
#   threefold_repetition          : 13
#   mean_steps                    : 12.5
#   checkmate_rate                : 97.5%
#
# --- Eval (1000 eps, movement_ratio=0.5) ---
#   checkmate                     : 981
#   missed_mate                   : 10
#   queen_hang                    : 3
#   stalemate                     : 1
#   threefold_repetition          : 5
#   mean_steps                    : 12.5
#   checkmate_rate                : 98.1%
# Mate-in-1 accuracy (greedy): 534/1000 = 53.4%
# 0.534

# %%
agent.train(
    n_episodes=100_000,
    eval_fens=eval_fens,
    eval_every=10_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 10416/100000  mean_return=8.166
#   [eval] ep=10416  checkmate=97.5%  mean_steps=12.3
# Episode 20336/100000  mean_return=8.212
#   [eval] ep=20336  checkmate=98.1%  mean_steps=12.3
# Episode 30256/100000  mean_return=8.270
#   [eval] ep=30256  checkmate=98.1%  mean_steps=12.3
# Episode 40176/100000  mean_return=8.201
#   [eval] ep=40176  checkmate=98.5%  mean_steps=12.3
# Episode 50096/100000  mean_return=8.182
#   [eval] ep=50096  checkmate=97.9%  mean_steps=12.4
# Episode 60016/100000  mean_return=8.221
#   [eval] ep=60016  checkmate=97.5%  mean_steps=12.4
# Episode 70432/100000  mean_return=8.290
#   [eval] ep=70432  checkmate=98.2%  mean_steps=12.3
# Episode 80352/100000  mean_return=8.198
#   [eval] ep=80352  checkmate=98.1%  mean_steps=12.3
# Episode 90272/100000  mean_return=8.096
#   [eval] ep=90272  checkmate=97.4%  mean_steps=12.0
# Episode 100192/100000  mean_return=8.258
#   [eval] ep=100192  checkmate=97.8%  mean_steps=12.3
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 973
#   missed_mate                   : 10
#   queen_hang                    : 1
#   stalemate                     : 1
#   threefold_repetition          : 15
#   mean_steps                    : 12.3
#   checkmate_rate                : 97.3%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 992
#   missed_mate                   : 4
#   queen_hang                    : 2
#   stalemate                     : 1
#   threefold_repetition          : 1
#   mean_steps                    : 12.2
#   checkmate_rate                : 99.2%
# Mate-in-1 accuracy (greedy): 525/1000 = 52.5%
# 0.525

# %%
agent.train(
    n_episodes=200_000,
    eval_fens=eval_fens,
    eval_every=10_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
#   [eval] ep=10416  checkmate=98.0%  mean_steps=12.2
# Episode 20336/200000  mean_return=8.190
#   [eval] ep=20336  checkmate=98.2%  mean_steps=12.1
#   [eval] ep=30256  checkmate=98.1%  mean_steps=11.9
# Episode 40176/200000  mean_return=8.259
#   [eval] ep=40176  checkmate=97.8%  mean_steps=12.0
#   [eval] ep=50096  checkmate=98.4%  mean_steps=12.1
# Episode 60016/200000  mean_return=8.318
#   [eval] ep=60016  checkmate=96.9%  mean_steps=12.0
#   [eval] ep=70432  checkmate=97.8%  mean_steps=11.8
# Episode 80352/200000  mean_return=8.217
#   [eval] ep=80352  checkmate=97.8%  mean_steps=11.8
#   [eval] ep=90272  checkmate=97.8%  mean_steps=11.9
# Episode 100192/200000  mean_return=8.327
#   [eval] ep=100192  checkmate=98.0%  mean_steps=11.8
#   [eval] ep=110112  checkmate=97.3%  mean_steps=11.7
# Episode 120032/200000  mean_return=8.221
#   [eval] ep=120032  checkmate=97.5%  mean_steps=11.7
#   [eval] ep=130448  checkmate=97.3%  mean_steps=11.7
# Episode 140368/200000  mean_return=8.375
#   [eval] ep=140368  checkmate=97.6%  mean_steps=11.7
#   [eval] ep=150288  checkmate=97.4%  mean_steps=11.8
# Episode 160208/200000  mean_return=8.310
#   [eval] ep=160208  checkmate=97.7%  mean_steps=11.7
#   [eval] ep=170128  checkmate=97.6%  mean_steps=12.1
# Episode 180048/200000  mean_return=8.268
#   [eval] ep=180048  checkmate=98.0%  mean_steps=11.9
#   [eval] ep=190464  checkmate=97.3%  mean_steps=11.7
# Episode 200384/200000  mean_return=8.420
#   [eval] ep=200384  checkmate=97.9%  mean_steps=11.7
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 970
#   missed_mate                   : 10
#   queen_hang                    : 3
#   threefold_repetition          : 17
#   mean_steps                    : 11.8
#   checkmate_rate                : 97.0%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 985
#   missed_mate                   : 10
#   queen_hang                    : 2
#   threefold_repetition          : 3
#   mean_steps                    : 12.1
#   checkmate_rate                : 98.5%
# Mate-in-1 accuracy (greedy): 547/1000 = 54.7%
# 0.547

# %%
agent.train(
    n_episodes=200_000,
    eval_fens=eval_fens,
    eval_every=20_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 20336/200000  mean_return=8.256
#   [eval] ep=20336  checkmate=97.9%  mean_steps=11.6
# Episode 40176/200000  mean_return=8.344
#   [eval] ep=40176  checkmate=98.5%  mean_steps=11.8
# Episode 60016/200000  mean_return=8.245
#   [eval] ep=60016  checkmate=98.0%  mean_steps=11.6
# Episode 80352/200000  mean_return=8.143
#   [eval] ep=80352  checkmate=98.4%  mean_steps=11.5
# Episode 100192/200000  mean_return=8.355
#   [eval] ep=100192  checkmate=98.1%  mean_steps=11.6
# Episode 120032/200000  mean_return=8.229
#   [eval] ep=120032  checkmate=98.2%  mean_steps=11.6
# Episode 140368/200000  mean_return=8.337
#   [eval] ep=140368  checkmate=97.6%  mean_steps=11.4
# Episode 160208/200000  mean_return=8.462
#   [eval] ep=160208  checkmate=98.1%  mean_steps=11.6
# Episode 180048/200000  mean_return=8.272
#   [eval] ep=180048  checkmate=98.3%  mean_steps=11.4
# Episode 200384/200000  mean_return=8.321
#   [eval] ep=200384  checkmate=97.7%  mean_steps=11.4
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 961
#   missed_mate                   : 13
#   queen_hang                    : 4
#   stalemate                     : 2
#   threefold_repetition          : 20
#   mean_steps                    : 11.3
#   checkmate_rate                : 96.1%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 985
#   missed_mate                   : 12
#   queen_hang                    : 2
#   threefold_repetition          : 1
#   mean_steps                    : 11.6
#   checkmate_rate                : 98.5%
# Mate-in-1 accuracy (greedy): 553/1000 = 55.3%
# 0.553

# %%
agent.train(
    n_episodes=100_000,
    eval_fens=eval_fens,
    eval_every=10_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 10416/100000  mean_return=8.245
#   [eval] ep=10416  checkmate=98.5%  mean_steps=11.4
# Episode 20336/100000  mean_return=8.346
#   [eval] ep=20336  checkmate=98.0%  mean_steps=11.4
# Episode 30256/100000  mean_return=8.356
#   [eval] ep=30256  checkmate=98.2%  mean_steps=11.5
# Episode 40176/100000  mean_return=8.318
#   [eval] ep=40176  checkmate=98.3%  mean_steps=11.5
# Episode 50096/100000  mean_return=8.341
#   [eval] ep=50096  checkmate=98.2%  mean_steps=11.5
# Episode 60016/100000  mean_return=8.392
#   [eval] ep=60016  checkmate=98.0%  mean_steps=11.6
# Episode 70432/100000  mean_return=8.334
#   [eval] ep=70432  checkmate=97.8%  mean_steps=11.5
# Episode 80352/100000  mean_return=8.270
#   [eval] ep=80352  checkmate=97.5%  mean_steps=11.3
# Episode 90272/100000  mean_return=8.382
#   [eval] ep=90272  checkmate=98.1%  mean_steps=11.3
# Episode 100192/100000  mean_return=8.306
#   [eval] ep=100192  checkmate=98.2%  mean_steps=11.5
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 977
#   missed_mate                   : 15
#   threefold_repetition          : 8
#   mean_steps                    : 11.4
#   checkmate_rate                : 97.7%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 987
#   missed_mate                   : 10
#   queen_hang                    : 2
#   threefold_repetition          : 1
#   mean_steps                    : 11.5
#   checkmate_rate                : 98.7%
# Mate-in-1 accuracy (greedy): 569/1000 = 56.9%
# 0.569

# %%
agent.train(
    n_episodes=100_000,
    eval_fens=eval_fens,
    eval_every=10_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 10416/100000  mean_return=8.379
#   [eval] ep=10416  checkmate=98.5%  mean_steps=11.5
# Episode 20336/100000  mean_return=8.274
#   [eval] ep=20336  checkmate=98.3%  mean_steps=11.5
# Episode 30256/100000  mean_return=8.276
#   [eval] ep=30256  checkmate=98.3%  mean_steps=11.5
# Episode 40176/100000  mean_return=8.335
#   [eval] ep=40176  checkmate=98.5%  mean_steps=11.4
# Episode 50096/100000  mean_return=8.387
#   [eval] ep=50096  checkmate=98.6%  mean_steps=11.4
# Episode 60016/100000  mean_return=8.347
#   [eval] ep=60016  checkmate=98.5%  mean_steps=11.5
# Episode 70432/100000  mean_return=8.281
#   [eval] ep=70432  checkmate=98.4%  mean_steps=11.4
# Episode 80352/100000  mean_return=8.431
#   [eval] ep=80352  checkmate=98.5%  mean_steps=11.5
# Episode 90272/100000  mean_return=8.318
#   [eval] ep=90272  checkmate=98.3%  mean_steps=11.4
# Episode 100192/100000  mean_return=8.233
#   [eval] ep=100192  checkmate=98.1%  mean_steps=11.5
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 968
#   missed_mate                   : 11
#   queen_hang                    : 1
#   threefold_repetition          : 20
#   mean_steps                    : 11.3
#   checkmate_rate                : 96.8%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 988
#   missed_mate                   : 8
#   queen_hang                    : 2
#   threefold_repetition          : 2
#   mean_steps                    : 11.6
#   checkmate_rate                : 98.8%
# Mate-in-1 accuracy (greedy): 535/1000 = 53.5%
# 0.535

# %%
agent.train(
    n_episodes=100_000,
    eval_fens=eval_fens,
    eval_every=10_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 10416/100000  mean_return=8.323
#   [eval] ep=10416  checkmate=98.5%  mean_steps=11.4
# Episode 20336/100000  mean_return=8.446
#   [eval] ep=20336  checkmate=98.3%  mean_steps=11.3
# Episode 30256/100000  mean_return=8.445
#   [eval] ep=30256  checkmate=97.8%  mean_steps=11.4
# Episode 40176/100000  mean_return=8.366
#   [eval] ep=40176  checkmate=98.3%  mean_steps=11.4
# Episode 50096/100000  mean_return=8.356
#   [eval] ep=50096  checkmate=98.4%  mean_steps=11.4
# Episode 60016/100000  mean_return=8.477
#   [eval] ep=60016  checkmate=98.8%  mean_steps=11.5
# Episode 70432/100000  mean_return=8.413
#   [eval] ep=70432  checkmate=98.7%  mean_steps=11.2
# Episode 80352/100000  mean_return=8.362
#   [eval] ep=80352  checkmate=98.6%  mean_steps=11.4
# Episode 90272/100000  mean_return=8.410
#   [eval] ep=90272  checkmate=98.6%  mean_steps=11.3
# Episode 100192/100000  mean_return=8.376
#   [eval] ep=100192  checkmate=98.7%  mean_steps=11.2
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 982
#   missed_mate                   : 10
#   queen_hang                    : 1
#   threefold_repetition          : 7
#   mean_steps                    : 11.1
#   checkmate_rate                : 98.2%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 986
#   missed_mate                   : 11
#   queen_hang                    : 1
#   stalemate                     : 1
#   threefold_repetition          : 1
#   mean_steps                    : 11.4
#   checkmate_rate                : 98.6%
# Mate-in-1 accuracy (greedy): 570/1000 = 57.0%
# 0.57

# %%
agent.save("kqk_ppo_v2_stage_4")
# Out:
# Saved → models/kqk_ppo_v2_stage_4.pt

# %%
agent.train(
    n_episodes=1_000_000,
    eval_fens=eval_fens,
    eval_every=100_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 100192/1000000  mean_return=8.423
#   [eval] ep=100192  checkmate=97.9%  mean_steps=11.0
# Episode 200384/1000000  mean_return=8.368
#   [eval] ep=200384  checkmate=98.6%  mean_steps=11.3
# Episode 300080/1000000  mean_return=8.434
#   [eval] ep=300080  checkmate=98.7%  mean_steps=11.2
# Episode 400272/1000000  mean_return=8.373
#   [eval] ep=400272  checkmate=98.5%  mean_steps=11.2
# Episode 500464/1000000  mean_return=8.487
#   [eval] ep=500464  checkmate=98.3%  mean_steps=11.0
# Episode 600160/1000000  mean_return=8.414
#   [eval] ep=600160  checkmate=98.4%  mean_steps=11.1
# Episode 700352/1000000  mean_return=8.499
#   [eval] ep=700352  checkmate=98.6%  mean_steps=10.9
# Episode 800048/1000000  mean_return=8.531
#   [eval] ep=800048  checkmate=98.4%  mean_steps=10.8
# Episode 900240/1000000  mean_return=8.452
#   [eval] ep=900240  checkmate=98.5%  mean_steps=10.9
# Episode 1000432/1000000  mean_return=8.509
#   [eval] ep=1000432  checkmate=98.4%  mean_steps=10.8
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 978
#   missed_mate                   : 10
#   queen_hang                    : 1
#   stalemate                     : 3
#   threefold_repetition          : 8
#   mean_steps                    : 10.5
#   checkmate_rate                : 97.8%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 981
#   missed_mate                   : 17
#   queen_hang                    : 1
#   threefold_repetition          : 1
#   mean_steps                    : 11.2
#   checkmate_rate                : 98.1%
# Mate-in-1 accuracy (greedy): 608/1000 = 60.8%
# 0.608

# %%
agent.train(
    n_episodes=1_000_000,
    eval_fens=eval_fens,
    eval_every=100_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 100192/1000000  mean_return=8.455
#   [eval] ep=100192  checkmate=98.6%  mean_steps=10.8
# Episode 200384/1000000  mean_return=8.437
#   [eval] ep=200384  checkmate=98.5%  mean_steps=10.5
# Episode 300080/1000000  mean_return=8.536
#   [eval] ep=300080  checkmate=98.8%  mean_steps=10.5
# Episode 400272/1000000  mean_return=8.462
#   [eval] ep=400272  checkmate=98.8%  mean_steps=10.6
# Episode 500464/1000000  mean_return=8.576
#   [eval] ep=500464  checkmate=98.7%  mean_steps=10.6
# Episode 600160/1000000  mean_return=8.566
#   [eval] ep=600160  checkmate=98.7%  mean_steps=10.6
# Episode 700352/1000000  mean_return=8.485
#   [eval] ep=700352  checkmate=98.5%  mean_steps=10.4
# Episode 800048/1000000  mean_return=8.508
#   [eval] ep=800048  checkmate=98.3%  mean_steps=10.5
# Episode 900240/1000000  mean_return=8.486
#   [eval] ep=900240  checkmate=98.6%  mean_steps=10.5
# Episode 1000432/1000000  mean_return=8.532
#   [eval] ep=1000432  checkmate=98.4%  mean_steps=10.5
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 977
#   missed_mate                   : 10
#   queen_hang                    : 3
#   threefold_repetition          : 10
#   mean_steps                    : 10.1
#   checkmate_rate                : 97.7%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 991
#   missed_mate                   : 9
#   mean_steps                    : 11.0
#   checkmate_rate                : 99.1%
# Mate-in-1 accuracy (greedy): 593/1000 = 59.3%
# 0.593

# %%
agent.train(
    n_episodes=1_000_000,
    eval_fens=eval_fens,
    eval_every=100_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 100192/1000000  mean_return=8.477
#   [eval] ep=100192  checkmate=98.6%  mean_steps=10.4
# Episode 200384/1000000  mean_return=8.448
#   [eval] ep=200384  checkmate=98.2%  mean_steps=10.5
# Episode 300080/1000000  mean_return=8.536
#   [eval] ep=300080  checkmate=98.5%  mean_steps=10.5
# Episode 400272/1000000  mean_return=8.510
#   [eval] ep=400272  checkmate=98.5%  mean_steps=10.3
# Episode 500464/1000000  mean_return=8.547
#   [eval] ep=500464  checkmate=98.8%  mean_steps=10.3
# Episode 600160/1000000  mean_return=8.530
#   [eval] ep=600160  checkmate=98.6%  mean_steps=10.2
# Episode 700352/1000000  mean_return=8.512
#   [eval] ep=700352  checkmate=98.7%  mean_steps=10.4
# Episode 800048/1000000  mean_return=8.517
#   [eval] ep=800048  checkmate=98.5%  mean_steps=10.2
# Episode 900240/1000000  mean_return=8.551
#   [eval] ep=900240  checkmate=98.5%  mean_steps=10.3
# Episode 1000432/1000000  mean_return=8.561
#   [eval] ep=1000432  checkmate=98.8%  mean_steps=10.1
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 976
#   missed_mate                   : 8
#   queen_hang                    : 2
#   stalemate                     : 1
#   threefold_repetition          : 13
#   mean_steps                    : 10.0
#   checkmate_rate                : 97.6%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 993
#   missed_mate                   : 6
#   queen_hang                    : 1
#   mean_steps                    : 11.1
#   checkmate_rate                : 99.3%
# Mate-in-1 accuracy (greedy): 609/1000 = 60.9%
# 0.609

# %%
agent.train(
    n_episodes=1_000_000,
    eval_fens=eval_fens,
    eval_every=100_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 100192/1000000  mean_return=8.585
#   [eval] ep=100192  checkmate=98.4%  mean_steps=10.2
# Episode 200384/1000000  mean_return=8.462
#   [eval] ep=200384  checkmate=98.6%  mean_steps=10.1
# Episode 300080/1000000  mean_return=8.566
#   [eval] ep=300080  checkmate=98.5%  mean_steps=10.3
# Episode 400272/1000000  mean_return=8.572
#   [eval] ep=400272  checkmate=99.0%  mean_steps=10.1
# Episode 500464/1000000  mean_return=8.625
#   [eval] ep=500464  checkmate=99.0%  mean_steps=10.2
# Episode 600160/1000000  mean_return=8.590
#   [eval] ep=600160  checkmate=99.0%  mean_steps=10.0
# Episode 700352/1000000  mean_return=8.607
#   [eval] ep=700352  checkmate=98.6%  mean_steps=10.1
# Episode 800048/1000000  mean_return=8.585
#   [eval] ep=800048  checkmate=98.9%  mean_steps=10.1
# Episode 900240/1000000  mean_return=8.589
#   [eval] ep=900240  checkmate=98.6%  mean_steps=10.0
# Episode 1000432/1000000  mean_return=8.597
#   [eval] ep=1000432  checkmate=98.9%  mean_steps=10.0
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 981
#   missed_mate                   : 8
#   stalemate                     : 1
#   threefold_repetition          : 10
#   mean_steps                    : 9.7
#   checkmate_rate                : 98.1%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 994
#   missed_mate                   : 4
#   stalemate                     : 1
#   threefold_repetition          : 1
#   mean_steps                    : 10.7
#   checkmate_rate                : 99.4%
# Mate-in-1 accuracy (greedy): 624/1000 = 62.4%
# 0.624

# %%
agent.save("kqk_ppo_v2_stage_4")
# Out:
# Saved → models/kqk_ppo_v2_stage_4.pt

# %%
agent.train(
    n_episodes=10_000_000,
    eval_fens=eval_fens,
    eval_every=100_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
#   [eval] ep=100192  checkmate=98.7%  mean_steps=10.1
#   [eval] ep=200384  checkmate=99.0%  mean_steps=10.0
#   [eval] ep=300080  checkmate=98.8%  mean_steps=9.9
#   [eval] ep=400272  checkmate=98.5%  mean_steps=9.8
#   [eval] ep=500464  checkmate=98.6%  mean_steps=9.9
#   [eval] ep=600160  checkmate=98.6%  mean_steps=9.8
#   [eval] ep=700352  checkmate=98.5%  mean_steps=9.9
#   [eval] ep=800048  checkmate=98.5%  mean_steps=9.9
#   [eval] ep=900240  checkmate=98.7%  mean_steps=9.8
# Episode 1000432/10000000  mean_return=8.629
#   [eval] ep=1000432  checkmate=99.0%  mean_steps=9.8
#   [eval] ep=1100128  checkmate=98.7%  mean_steps=9.7
#   [eval] ep=1200320  checkmate=98.7%  mean_steps=9.8
#   [eval] ep=1300016  checkmate=98.5%  mean_steps=9.7
#   [eval] ep=1400208  checkmate=98.7%  mean_steps=9.7
#   [eval] ep=1500400  checkmate=98.6%  mean_steps=9.7
#   [eval] ep=1600096  checkmate=98.5%  mean_steps=9.7
#   [eval] ep=1700288  checkmate=98.6%  mean_steps=9.7
#   [eval] ep=1800480  checkmate=98.7%  mean_steps=9.7
#   [eval] ep=1900176  checkmate=98.6%  mean_steps=9.7
# Episode 2000368/10000000  mean_return=8.627
#   [eval] ep=2000368  checkmate=98.5%  mean_steps=9.7
#   [eval] ep=2100064  checkmate=98.6%  mean_steps=9.6
#   [eval] ep=2200256  checkmate=98.9%  mean_steps=9.6
#   [eval] ep=2300448  checkmate=98.6%  mean_steps=9.6
#   [eval] ep=2400144  checkmate=98.6%  mean_steps=9.6
#   [eval] ep=2500336  checkmate=98.8%  mean_steps=9.5
#   [eval] ep=2600032  checkmate=98.4%  mean_steps=9.5
#   [eval] ep=2700224  checkmate=98.8%  mean_steps=9.6
#   [eval] ep=2800416  checkmate=98.5%  mean_steps=9.5
#   [eval] ep=2900112  checkmate=98.7%  mean_steps=9.5
# Episode 3000304/10000000  mean_return=8.646
#   [eval] ep=3000304  checkmate=98.5%  mean_steps=9.5
#   [eval] ep=3100000  checkmate=98.8%  mean_steps=9.4
#   [eval] ep=3200192  checkmate=99.0%  mean_steps=9.6
#   [eval] ep=3300384  checkmate=98.6%  mean_steps=9.6
#   [eval] ep=3400080  checkmate=98.7%  mean_steps=9.5
#   [eval] ep=3500272  checkmate=98.6%  mean_steps=9.4
#   [eval] ep=3600464  checkmate=98.8%  mean_steps=9.5
#   [eval] ep=3700160  checkmate=98.4%  mean_steps=9.2
#   [eval] ep=3800352  checkmate=99.0%  mean_steps=9.3
#   [eval] ep=3900048  checkmate=99.0%  mean_steps=9.3
# Episode 4000240/10000000  mean_return=8.714
#   [eval] ep=4000240  checkmate=98.7%  mean_steps=9.3
#   [eval] ep=4100432  checkmate=98.7%  mean_steps=9.2
#   [eval] ep=4200128  checkmate=98.7%  mean_steps=9.4
#   [eval] ep=4300320  checkmate=99.0%  mean_steps=9.3
#   [eval] ep=4400016  checkmate=98.5%  mean_steps=9.3
#   [eval] ep=4500208  checkmate=99.0%  mean_steps=9.2
#   [eval] ep=4600400  checkmate=98.8%  mean_steps=9.3
#   [eval] ep=4700096  checkmate=98.9%  mean_steps=9.2
#   [eval] ep=4800288  checkmate=98.7%  mean_steps=9.3
#   [eval] ep=4900480  checkmate=98.9%  mean_steps=9.3
# Episode 5000176/10000000  mean_return=8.664
#   [eval] ep=5000176  checkmate=98.8%  mean_steps=9.2
#   [eval] ep=5100368  checkmate=99.0%  mean_steps=9.3
#   [eval] ep=5200064  checkmate=99.0%  mean_steps=9.3
#   [eval] ep=5300256  checkmate=98.9%  mean_steps=9.1
#   [eval] ep=5400448  checkmate=98.8%  mean_steps=9.3
#   [eval] ep=5500144  checkmate=98.9%  mean_steps=9.2
#   [eval] ep=5600336  checkmate=98.9%  mean_steps=9.1
#   [eval] ep=5700032  checkmate=98.8%  mean_steps=9.2
#   [eval] ep=5800224  checkmate=98.6%  mean_steps=9.0
#   [eval] ep=5900416  checkmate=98.9%  mean_steps=9.1
# Episode 6000112/10000000  mean_return=8.641
#   [eval] ep=6000112  checkmate=98.8%  mean_steps=9.0
#   [eval] ep=6100304  checkmate=99.1%  mean_steps=9.0
#   [eval] ep=6200000  checkmate=99.0%  mean_steps=9.0
#   [eval] ep=6300192  checkmate=98.6%  mean_steps=8.9
#   [eval] ep=6400384  checkmate=98.7%  mean_steps=9.0
#   [eval] ep=6500080  checkmate=98.9%  mean_steps=9.0
#   [eval] ep=6600272  checkmate=98.6%  mean_steps=9.1
#   [eval] ep=6700464  checkmate=98.8%  mean_steps=8.9
#   [eval] ep=6800160  checkmate=98.9%  mean_steps=9.0
#   [eval] ep=6900352  checkmate=98.9%  mean_steps=9.1
# Episode 7000048/10000000  mean_return=8.677
#   [eval] ep=7000048  checkmate=98.7%  mean_steps=9.0
#   [eval] ep=7100240  checkmate=98.8%  mean_steps=9.0
#   [eval] ep=7200432  checkmate=98.8%  mean_steps=9.0
#   [eval] ep=7300128  checkmate=99.0%  mean_steps=8.9
#   [eval] ep=7400320  checkmate=98.6%  mean_steps=8.9
#   [eval] ep=7500016  checkmate=98.9%  mean_steps=8.9
#   [eval] ep=7600208  checkmate=99.1%  mean_steps=8.8
#   [eval] ep=7700400  checkmate=99.0%  mean_steps=8.9
#   [eval] ep=7800096  checkmate=98.7%  mean_steps=8.8
#   [eval] ep=7900288  checkmate=98.9%  mean_steps=8.9
# Episode 8000480/10000000  mean_return=8.758
#   [eval] ep=8000480  checkmate=98.8%  mean_steps=8.8
#   [eval] ep=8100176  checkmate=98.7%  mean_steps=8.8
#   [eval] ep=8200368  checkmate=98.9%  mean_steps=8.8
#   [eval] ep=8300064  checkmate=99.0%  mean_steps=8.8
#   [eval] ep=8400256  checkmate=98.7%  mean_steps=8.7
#   [eval] ep=8500448  checkmate=98.9%  mean_steps=8.9
#   [eval] ep=8600144  checkmate=98.8%  mean_steps=8.8
#   [eval] ep=8700336  checkmate=99.0%  mean_steps=8.8
#   [eval] ep=8800032  checkmate=98.8%  mean_steps=8.8
#   [eval] ep=8900224  checkmate=98.9%  mean_steps=8.7
# Episode 9000416/10000000  mean_return=8.793
#   [eval] ep=9000416  checkmate=98.8%  mean_steps=8.9
#   [eval] ep=9100112  checkmate=98.5%  mean_steps=8.6
#   [eval] ep=9200304  checkmate=98.8%  mean_steps=8.7
#   [eval] ep=9300000  checkmate=99.1%  mean_steps=8.8
#   [eval] ep=9400192  checkmate=98.9%  mean_steps=8.7
#   [eval] ep=9500384  checkmate=98.8%  mean_steps=8.7
#   [eval] ep=9600080  checkmate=98.8%  mean_steps=8.8
#   [eval] ep=9700272  checkmate=98.8%  mean_steps=8.9
#   [eval] ep=9800464  checkmate=98.8%  mean_steps=8.8
#   [eval] ep=9900160  checkmate=99.0%  mean_steps=8.7
# Episode 10000352/10000000  mean_return=8.670
#   [eval] ep=10000352  checkmate=98.9%  mean_steps=8.8
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 984
#   missed_mate                   : 8
#   queen_hang                    : 1
#   stalemate                     : 1
#   threefold_repetition          : 6
#   mean_steps                    : 8.3
#   checkmate_rate                : 98.4%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 993
#   missed_mate                   : 6
#   queen_hang                    : 1
#   mean_steps                    : 9.4
#   checkmate_rate                : 99.3%
# Mate-in-1 accuracy (greedy): 641/1000 = 64.1%
# 0.641

# %%
agent.train(
    n_episodes=1_000_000,
    eval_fens=eval_fens,
    eval_every=100_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 100192/1000000  mean_return=8.689
#   [eval] ep=100192  checkmate=98.8%  mean_steps=8.7
# Episode 200384/1000000  mean_return=8.798
#   [eval] ep=200384  checkmate=98.8%  mean_steps=8.7
# Episode 300080/1000000  mean_return=8.624
#   [eval] ep=300080  checkmate=98.8%  mean_steps=8.6
# Episode 400272/1000000  mean_return=8.712
#   [eval] ep=400272  checkmate=99.1%  mean_steps=8.7
# Episode 500464/1000000  mean_return=8.706
#   [eval] ep=500464  checkmate=99.1%  mean_steps=8.7
# Episode 600160/1000000  mean_return=8.779
#   [eval] ep=600160  checkmate=99.0%  mean_steps=8.8
# Episode 700352/1000000  mean_return=8.783
#   [eval] ep=700352  checkmate=98.8%  mean_steps=8.6
# Episode 800048/1000000  mean_return=8.680
#   [eval] ep=800048  checkmate=98.8%  mean_steps=8.6
# Episode 900240/1000000  mean_return=8.753
#   [eval] ep=900240  checkmate=98.8%  mean_steps=8.5
# Episode 1000432/1000000  mean_return=8.764
#   [eval] ep=1000432  checkmate=99.1%  mean_steps=8.7
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 984
#   missed_mate                   : 10
#   threefold_repetition          : 6
#   mean_steps                    : 8.0
#   checkmate_rate                : 98.4%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 985
#   missed_mate                   : 12
#   queen_hang                    : 2
#   threefold_repetition          : 1
#   mean_steps                    : 9.2
#   checkmate_rate                : 98.5%
# Mate-in-1 accuracy (greedy): 644/1000 = 64.4%
# 0.644

# %%
agent.save("kqk_ppo_v2_stage_4")
# Out:
# Saved → models/kqk_ppo_v2_stage_4.pt

# %%
agent.train(
    n_episodes=1_000_000,
    eval_fens=eval_fens,
    eval_every=100_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 100192/1000000  mean_return=8.719
#   [eval] ep=100192  checkmate=99.0%  mean_steps=8.6
# Episode 200384/1000000  mean_return=8.723
#   [eval] ep=200384  checkmate=98.9%  mean_steps=8.5
# Episode 300080/1000000  mean_return=8.714
#   [eval] ep=300080  checkmate=98.9%  mean_steps=8.6
# Episode 400272/1000000  mean_return=8.720
#   [eval] ep=400272  checkmate=98.8%  mean_steps=8.6
# Episode 500464/1000000  mean_return=8.791
#   [eval] ep=500464  checkmate=98.6%  mean_steps=8.6
# Episode 600160/1000000  mean_return=8.704
#   [eval] ep=600160  checkmate=98.7%  mean_steps=8.6
# Episode 700352/1000000  mean_return=8.756
#   [eval] ep=700352  checkmate=98.5%  mean_steps=8.5
# Episode 800048/1000000  mean_return=8.729
#   [eval] ep=800048  checkmate=98.8%  mean_steps=8.5
# Episode 900240/1000000  mean_return=8.739
#   [eval] ep=900240  checkmate=98.9%  mean_steps=8.5
# Episode 1000432/1000000  mean_return=8.784
#   [eval] ep=1000432  checkmate=98.6%  mean_steps=8.5
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 991
#   missed_mate                   : 5
#   queen_hang                    : 1
#   threefold_repetition          : 3
#   mean_steps                    : 7.9
#   checkmate_rate                : 99.1%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 983
#   missed_mate                   : 11
#   threefold_repetition          : 6
#   mean_steps                    : 9.1
#   checkmate_rate                : 98.3%
# Mate-in-1 accuracy (greedy): 640/1000 = 64.0%
# 0.64

# %%
agent.train(
    n_episodes=100_000,
    eval_fens=eval_fens,
    eval_every=10_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 10416/100000  mean_return=8.768
#   [eval] ep=10416  checkmate=98.8%  mean_steps=8.5
# Episode 20336/100000  mean_return=8.742
#   [eval] ep=20336  checkmate=99.0%  mean_steps=8.5
# Episode 30256/100000  mean_return=8.761
#   [eval] ep=30256  checkmate=98.6%  mean_steps=8.5
# Episode 40176/100000  mean_return=8.762
#   [eval] ep=40176  checkmate=98.9%  mean_steps=8.6
# Episode 50096/100000  mean_return=8.763
#   [eval] ep=50096  checkmate=98.9%  mean_steps=8.5
# Episode 60016/100000  mean_return=8.803
#   [eval] ep=60016  checkmate=98.7%  mean_steps=8.6
# Episode 70432/100000  mean_return=8.787
#   [eval] ep=70432  checkmate=98.9%  mean_steps=8.5
# Episode 80352/100000  mean_return=8.777
#   [eval] ep=80352  checkmate=98.8%  mean_steps=8.6
# Episode 90272/100000  mean_return=8.755
#   [eval] ep=90272  checkmate=98.9%  mean_steps=8.5
# Episode 100192/100000  mean_return=8.682
#   [eval] ep=100192  checkmate=98.8%  mean_steps=8.6
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 991
#   missed_mate                   : 5
#   queen_hang                    : 2
#   threefold_repetition          : 2
#   mean_steps                    : 7.9
#   checkmate_rate                : 99.1%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 987
#   missed_mate                   : 6
#   stalemate                     : 1
#   threefold_repetition          : 6
#   mean_steps                    : 9.2
#   checkmate_rate                : 98.7%
# Mate-in-1 accuracy (greedy): 608/1000 = 60.8%
# 0.608

# %%
agent.train(
    n_episodes=100_000,
    eval_fens=eval_fens,
    eval_every=10_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 10416/100000  mean_return=8.693
#   [eval] ep=10416  checkmate=99.1%  mean_steps=8.6
# Episode 20336/100000  mean_return=8.758
#   [eval] ep=20336  checkmate=98.8%  mean_steps=8.5
# Episode 30256/100000  mean_return=8.739
#   [eval] ep=30256  checkmate=98.8%  mean_steps=8.6
# Episode 40176/100000  mean_return=8.793
#   [eval] ep=40176  checkmate=98.8%  mean_steps=8.6
# Episode 50096/100000  mean_return=8.716
#   [eval] ep=50096  checkmate=98.4%  mean_steps=8.4
# Episode 60016/100000  mean_return=8.831
#   [eval] ep=60016  checkmate=98.9%  mean_steps=8.4
# Episode 70432/100000  mean_return=8.719
#   [eval] ep=70432  checkmate=98.8%  mean_steps=8.6
# Episode 80352/100000  mean_return=8.740
#   [eval] ep=80352  checkmate=98.9%  mean_steps=8.5
# Episode 90272/100000  mean_return=8.806
#   [eval] ep=90272  checkmate=98.4%  mean_steps=8.7
# Episode 100192/100000  mean_return=8.663
#   [eval] ep=100192  checkmate=98.4%  mean_steps=8.5
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 983
#   missed_mate                   : 15
#   threefold_repetition          : 2
#   mean_steps                    : 7.8
#   checkmate_rate                : 98.3%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 986
#   missed_mate                   : 11
#   queen_hang                    : 2
#   threefold_repetition          : 1
#   mean_steps                    : 9.2
#   checkmate_rate                : 98.6%
# Mate-in-1 accuracy (greedy): 655/1000 = 65.5%
# 0.655

# %%
agent.save("kqk_ppo_v2_stage_4")
# Out:
# Saved → models/kqk_ppo_v2_stage_4.pt

# %%
agent.curriculum_ratio = 0.4
agent.train(
    n_episodes=100_000,
    eval_fens=eval_fens,
    eval_every=10_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 10416/100000  mean_return=8.646
#   [eval] ep=10416  checkmate=98.8%  mean_steps=8.7
# Episode 20336/100000  mean_return=8.591
#   [eval] ep=20336  checkmate=98.6%  mean_steps=8.6
# Episode 30256/100000  mean_return=8.656
#   [eval] ep=30256  checkmate=98.5%  mean_steps=8.4
# Episode 40176/100000  mean_return=8.680
#   [eval] ep=40176  checkmate=98.8%  mean_steps=8.5
# Episode 50096/100000  mean_return=8.686
#   [eval] ep=50096  checkmate=98.8%  mean_steps=8.6
# Episode 60016/100000  mean_return=8.672
#   [eval] ep=60016  checkmate=98.5%  mean_steps=8.5
# Episode 70432/100000  mean_return=8.715
#   [eval] ep=70432  checkmate=98.7%  mean_steps=8.5
# Episode 80352/100000  mean_return=8.647
#   [eval] ep=80352  checkmate=98.5%  mean_steps=8.4
# Episode 90272/100000  mean_return=8.587
#   [eval] ep=90272  checkmate=98.7%  mean_steps=8.6
# Episode 100192/100000  mean_return=8.681
#   [eval] ep=100192  checkmate=98.8%  mean_steps=8.5
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 983
#   missed_mate                   : 10
#   stalemate                     : 1
#   threefold_repetition          : 6
#   mean_steps                    : 7.9
#   checkmate_rate                : 98.3%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 990
#   missed_mate                   : 6
#   threefold_repetition          : 4
#   mean_steps                    : 8.9
#   checkmate_rate                : 99.0%
# Mate-in-1 accuracy (greedy): 628/1000 = 62.8%
# 0.628

# %%
agent.train(
    n_episodes=100_000,
    eval_fens=eval_fens,
    eval_every=10_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 10416/100000  mean_return=8.624
#   [eval] ep=10416  checkmate=98.6%  mean_steps=8.5
# Episode 20336/100000  mean_return=8.725
#   [eval] ep=20336  checkmate=98.7%  mean_steps=8.5
# Episode 30256/100000  mean_return=8.629
#   [eval] ep=30256  checkmate=98.2%  mean_steps=8.6
# Episode 40176/100000  mean_return=8.654
#   [eval] ep=40176  checkmate=98.7%  mean_steps=8.5
# Episode 50096/100000  mean_return=8.597
#   [eval] ep=50096  checkmate=98.6%  mean_steps=8.5
# Episode 60016/100000  mean_return=8.601
#   [eval] ep=60016  checkmate=98.6%  mean_steps=8.5
# Episode 70432/100000  mean_return=8.550
#   [eval] ep=70432  checkmate=98.9%  mean_steps=8.4
# Episode 80352/100000  mean_return=8.643
#   [eval] ep=80352  checkmate=98.9%  mean_steps=8.5
# Episode 90272/100000  mean_return=8.682
#   [eval] ep=90272  checkmate=98.9%  mean_steps=8.4
# Episode 100192/100000  mean_return=8.573
#   [eval] ep=100192  checkmate=98.9%  mean_steps=8.5
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 990
#   missed_mate                   : 8
#   threefold_repetition          : 2
#   mean_steps                    : 7.8
#   checkmate_rate                : 99.0%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 987
#   missed_mate                   : 12
#   queen_hang                    : 1
#   mean_steps                    : 8.9
#   checkmate_rate                : 98.7%
# Mate-in-1 accuracy (greedy): 637/1000 = 63.7%
# 0.637

# %%
agent.train(
    n_episodes=100_000,
    eval_fens=eval_fens,
    eval_every=10_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
# Episode 10416/100000  mean_return=8.586
#   [eval] ep=10416  checkmate=98.7%  mean_steps=8.5
# Episode 20336/100000  mean_return=8.642
#   [eval] ep=20336  checkmate=98.5%  mean_steps=8.5
# Episode 30256/100000  mean_return=8.683
#   [eval] ep=30256  checkmate=98.8%  mean_steps=8.4
# Episode 40176/100000  mean_return=8.697
#   [eval] ep=40176  checkmate=98.5%  mean_steps=8.5
# Episode 50096/100000  mean_return=8.615
#   [eval] ep=50096  checkmate=98.8%  mean_steps=8.4
# Episode 60016/100000  mean_return=8.601
#   [eval] ep=60016  checkmate=98.7%  mean_steps=8.6
# Episode 70432/100000  mean_return=8.565
#   [eval] ep=70432  checkmate=98.8%  mean_steps=8.6
# Episode 80352/100000  mean_return=8.650
#   [eval] ep=80352  checkmate=98.9%  mean_steps=8.5
# Episode 90272/100000  mean_return=8.597
#   [eval] ep=90272  checkmate=98.9%  mean_steps=8.6
# Episode 100192/100000  mean_return=8.640
#   [eval] ep=100192  checkmate=98.7%  mean_steps=8.6
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 991
#   missed_mate                   : 9
#   mean_steps                    : 8.0
#   checkmate_rate                : 99.1%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 992
#   missed_mate                   : 8
#   mean_steps                    : 9.1
#   checkmate_rate                : 99.2%
# Mate-in-1 accuracy (greedy): 624/1000 = 62.4%
# 0.624

# %%
agent.train(
    n_episodes=200_000,
    eval_fens=eval_fens,
    eval_every=10_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
# Out:
#   [eval] ep=10416  checkmate=98.8%  mean_steps=8.4
# Episode 20336/200000  mean_return=8.668
#   [eval] ep=20336  checkmate=98.6%  mean_steps=8.4
#   [eval] ep=30256  checkmate=98.9%  mean_steps=8.5
# Episode 40176/200000  mean_return=8.658
#   [eval] ep=40176  checkmate=98.6%  mean_steps=8.5
#   [eval] ep=50096  checkmate=98.7%  mean_steps=8.4
# Episode 60016/200000  mean_return=8.651
#   [eval] ep=60016  checkmate=98.9%  mean_steps=8.5
#   [eval] ep=70432  checkmate=98.9%  mean_steps=8.5
# Episode 80352/200000  mean_return=8.653
#   [eval] ep=80352  checkmate=98.7%  mean_steps=8.5
#   [eval] ep=90272  checkmate=98.8%  mean_steps=8.5
# Episode 100192/200000  mean_return=8.725
#   [eval] ep=100192  checkmate=98.5%  mean_steps=8.5
#   [eval] ep=110112  checkmate=98.7%  mean_steps=8.4
# Episode 120032/200000  mean_return=8.645
#   [eval] ep=120032  checkmate=99.0%  mean_steps=8.5
#   [eval] ep=130448  checkmate=98.8%  mean_steps=8.4
# Episode 140368/200000  mean_return=8.749
#   [eval] ep=140368  checkmate=98.8%  mean_steps=8.4
#   [eval] ep=150288  checkmate=98.6%  mean_steps=8.4
# Episode 160208/200000  mean_return=8.727
#   [eval] ep=160208  checkmate=98.8%  mean_steps=8.4
#   [eval] ep=170128  checkmate=98.6%  mean_steps=8.5
# Episode 180048/200000  mean_return=8.683
#   [eval] ep=180048  checkmate=98.7%  mean_steps=8.4
#   [eval] ep=190464  checkmate=98.8%  mean_steps=8.5
# Episode 200384/200000  mean_return=8.602
#   [eval] ep=200384  checkmate=98.9%  mean_steps=8.5
# Training history saved → /home/anass/School/chessMate/agents/v11/train_history.json
#
# --- Eval (1000 eps, movement_ratio=1.0) ---
#   checkmate                     : 988
#   missed_mate                   : 10
#   stalemate                     : 1
#   threefold_repetition          : 1
#   mean_steps                    : 7.9
#   checkmate_rate                : 98.8%
#
# --- Eval (1000 eps, movement_ratio=0.0) ---
#   checkmate                     : 989
#   missed_mate                   : 10
#   threefold_repetition          : 1
#   mean_steps                    : 9.1
#   checkmate_rate                : 98.9%
# Mate-in-1 accuracy (greedy): 643/1000 = 64.3%
# 0.643

# %%
agent.train(
    n_episodes=200_000,
    eval_fens=eval_fens,
    eval_every=10_000
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=1.0
)

agent.evaluate(
    n_episodes=1000,
    movement_ratio=0.0
)

agent.evaluate_mate_in_one(
    n_episodes=1000,
    greedy=True
)
