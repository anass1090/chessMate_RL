# %%
from agents.v3.reinforce_agent import ReinforceAgentV3

# %%
agent = ReinforceAgentV3()
agent.train(n_episodes=20_000, gamma=0.99, log_every=10000, n_envs=16, update_freq=256)
# Out:
# Using device: cuda
# Generating 500 mate-in-1 positions...
# Done.

# %%
agent.save("kqk3_reinforce")

# %%
agent2 = ReinforceAgentV3()
agent2.load("kqk3_reinforce")
agent2.evaluate(n_episodes=10000)

# %%
agent2.evaluate_mate_in_one(n_episodes=500)
